# %% [markdown]
# ## Load The Data

# %%
import pandas as pd
import numpy as np

lines = pd.read_csv('C:/Users/suras/Downloads/archive/merge_df.csv', header=0)
lines=lines.iloc[1:5000] 
lines
# Out:
#                         english                      arabic
# 1                          Run!                       اركض!
# 2                         Help!                     النجدة!
# 3                         Jump!                       اقفز!
# 4                         Stop!                         قف!
# 5                        Go on.                       داوم.
# ...                         ...                         ...
# 4995  Tom is reading the Bible.           توم يقرأ الإنجيل.
# 4996  Tom is wanted for murder.      توم مطلوب بتهمة القتل.
# 4997  Tom married a local girl.         توم تجوز فتاة محلية
# 4998  Tom often goes to Boston.  يذهب توم إلى بوسطن كثيرًا.
# 4999  Tom paid for the tickets.        دفع توم ثمن التذاكر.
#
# [4999 rows x 2 columns]

# %% [markdown]
# ## Design an Encoder & Decoder for the Model
# ## Preprocessing & Tokenizing the Data

# %%
# Encoder Input :: English Sentences
from tensorflow.keras import preprocessing
eng_lines = list()
for line in lines.english:
  eng_lines.append(line)
    
tokenizer= preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(eng_lines)
tokenized_eng_lines =tokenizer.texts_to_sequences(eng_lines)

length_list=list()
for tokens in tokenized_eng_lines:
  length_list.append(len(tokens))
    
max_input_length= np.array(length_list).max()

print("English sentence max length ::", max_input_length)
padded_eng_lines= preprocessing.sequence.pad_sequences(tokenized_eng_lines, maxlen=max_input_length, padding='post')

encoder_input_data=np.array(padded_eng_lines)
print('Encoder Input Data shape ::', encoder_input_data.shape)

eng_word_dict= tokenizer.word_index
num_eng_words= len(eng_word_dict)+1

print('Number of English tokens ::', num_eng_words)
# Out:
# English sentence max length :: 7
# Encoder Input Data shape :: (4999, 7)
# Number of English tokens :: 2011

# %%
# Decoder Input :: Arabic Sentences
ara_lines = list()
for line in lines.arabic:
    ara_lines = ['<START> ' + line + ' <END>' for line in lines.arabic]


tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(ara_lines)
tokenized_ara_lines = tokenizer.texts_to_sequences(ara_lines)

length_list = list()
for tokens in tokenized_ara_lines:
    length_list.append(len(tokens))

max_output_length = np.array(length_list).max()
print('Arabic sentence max length ::', max_output_length)


padded_ara_lines = preprocessing.sequence.pad_sequences(tokenized_ara_lines, maxlen=max_output_length, padding='post')

decoder_input_data=np.array(padded_ara_lines)
print('Decoder Input Data Shape ::', decoder_input_data.shape)

ara_word_dict = tokenizer.word_index
num_ara_tokens = len(ara_word_dict) + 1

print('Number of Arabic tokens ::', num_ara_tokens)
# Out:
# Arabic sentence max length :: 10
# Decoder Input Data Shape :: (4999, 10)
# Number of Arabic tokens :: 5041

# %%
# Decoder Output :: Arabic Sentences -Preprocessed-
from tensorflow.keras import utils
decoder_output_data=list()
for token in tokenized_ara_lines:
   decoder_output_data.append(token[1:])

padded_ara_lines=preprocessing.sequence.pad_sequences(decoder_output_data,maxlen=max_output_length,padding='post')
onehot_ara_lines= utils.to_categorical(padded_ara_lines,num_ara_tokens)

decoder_output_data=np.array(onehot_ara_lines)
print('Decoder Output Data Shape ::',decoder_output_data.shape)
# Out:
# Decoder Output Data Shape :: (4999, 10, 5041)

# %% [markdown]
# ## Building LSTM model

# %%
import tensorflow.keras as k
from tensorflow.keras import layers, activations, models, preprocessing, utils
encoder_inputs= k.layers.Input(shape=(None,))
encoder_embedding= k.layers.Embedding(num_eng_words, 256, mask_zero=True)(encoder_inputs)
encoder_outputs, state_h, state_c= k.layers.LSTM(128, return_state=True)(encoder_embedding)
encoder_states= [state_h, state_c]

decoder_inputs= k.layers.Input (shape=(None,))
decoder_embedding= k.layers.Embedding(num_ara_tokens, 256, mask_zero=True)(decoder_inputs)
decoder_lstm= k.layers.LSTM(128, return_state=True, return_sequences=True)
decoder_outputs,_,_= decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense= k.layers.Dense(num_ara_tokens, activation= k.activations.softmax)
output= decoder_dense(decoder_outputs)

model= k.models.Model([encoder_inputs, decoder_inputs], output)
model.compile(optimizer= k.optimizers.RMSprop(), loss='categorical_crossentropy')
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, None, 256) │    514,816 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, None)      │          0 │ input_layer[0][0] │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, None, 256) │  1,290,496 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 128),     │    197,120 │ embedding[0][0],  │
# │                     │ (None, 128),      │            │ not_equal[0][0]   │
# │                     │ (None, 128)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, None,     │    197,120 │ embedding_1[0][0… │
# │                     │ 128), (None,      │            │ lstm[0][1],       │
# │                     │ 128), (None,      │            │ lstm[0][2]        │
# │                     │ 128)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, None,      │    650,289 │ lstm_1[0][0]      │
# │                     │ 5041)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,849,841 (10.87 MB)
#  Trainable params: 2,849,841 (10.87 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train The Model

# %%
model.fit([encoder_input_data,decoder_input_data],decoder_output_data,batch_size=128,epochs=200)
# Out:
# Epoch 1/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 143ms/step - loss: 8.1172
# Epoch 2/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - loss: 5.3386
# Epoch 3/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - loss: 5.0386
# Epoch 4/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 4.7693
# Epoch 5/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - loss: 4.6357
# Epoch 6/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 170ms/step - loss: 4.5757
# Epoch 7/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 4.5306
# Epoch 8/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - loss: 4.4975
# Epoch 9/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 4.4743
# Epoch 10/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - loss: 4.4373
# Epoch 11/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - loss: 4.4012
# Epoch 12/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 4.3567
# Epoch 13/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - loss: 4.3285
# Epoch 14/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 4.2730
# Epoch 15/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 4.2335
# Epoch 16/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 4.1807
# Epoch 17/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 4.1237
# Epoch 18/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 4.0897
# Epoch 19/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 4.0653
# Epoch 20/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 3.9828
# Epoch 21/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 3.9601
# Epoch 22/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 3.9110
# Epoch 23/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 3.8672
# Epoch 24/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 3.8331
# Epoch 25/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 3.7803
# Epoch 26/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 3.7603
# Epoch 27/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 3.7170
# Epoch 28/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 3.7141
# Epoch 29/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 3.6462
# Epoch 30/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 3.6230
# Epoch 31/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 3.5738
# Epoch 32/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 3.5550
# Epoch 33/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 3.5124
# Epoch 34/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 3.5024
# Epoch 35/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - loss: 3.4455
# Epoch 36/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 3.4101
# Epoch 37/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 3.3870
# Epoch 38/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - loss: 3.3630
# Epoch 39/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 3.3235
# Epoch 40/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 3.3050
# Epoch 41/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 3.2626
# Epoch 42/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 3.2193
# Epoch 43/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 3.2035
# Epoch 44/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 3.1620
# Epoch 45/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 3.1400
# Epoch 46/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 3.0958
# Epoch 47/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 3.0712
# Epoch 48/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 3.0372
# Epoch 49/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 3.0199
# Epoch 50/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - loss: 2.9862
# Epoch 51/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 2.9544
# Epoch 52/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 2.9280
# Epoch 53/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 2.8872
# Epoch 54/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 2.8702
# Epoch 55/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 2.8331
# Epoch 56/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 2.8134
# Epoch 57/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 2.7907
# Epoch 58/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 2.7457
# Epoch 59/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 2.7323
# Epoch 60/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 2.6980
# Epoch 61/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 2.6806
# Epoch 62/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - loss: 2.6503
# Epoch 63/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 2.6176
# Epoch 64/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 2.5956
# Epoch 65/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 2.5748
# Epoch 66/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 2.5450
# Epoch 67/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 2.5093
# Epoch 68/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 2.5024
# Epoch 69/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 2.4737
# Epoch 70/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - loss: 2.4533
# Epoch 71/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 2.4105
# Epoch 72/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 2.4027
# Epoch 73/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - loss: 2.3572
# Epoch 74/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 2.3425
# Epoch 75/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 2.3257
# Epoch 76/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 2.2969
# Epoch 77/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 2.2875
# Epoch 78/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - loss: 2.2620
# Epoch 79/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 2.2322
# Epoch 80/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 2.1987
# Epoch 81/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 2.1875
# Epoch 82/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 2.1436
# Epoch 83/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 2.1311
# Epoch 84/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - loss: 2.1065
# Epoch 85/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 2.0992
# Epoch 86/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 2.0630
# Epoch 87/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 2.0364
# Epoch 88/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 2.0279
# Epoch 89/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - loss: 2.0095
# Epoch 90/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 1.9775
# Epoch 91/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 1.9511
# Epoch 92/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 1.9285
# Epoch 93/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 1.9165
# Epoch 94/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 1.8908
# Epoch 95/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 1.8710
# Epoch 96/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 1.8477
# Epoch 97/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 1.8299
# Epoch 98/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 1.8084
# Epoch 99/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 1.7988
# Epoch 100/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 1.7682
# Epoch 101/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 1.7419
# Epoch 102/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 1.7385
# Epoch 103/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 1.7127
# Epoch 104/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 1.6799
# Epoch 105/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 1.6645
# Epoch 106/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 169ms/step - loss: 1.6571
# Epoch 107/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 1.6277
# Epoch 108/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 1.6110
# Epoch 109/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 1.6040
# Epoch 110/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 1.5869
# Epoch 111/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 1.5664
# Epoch 112/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 1.5374
# Epoch 113/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 1.5299
# Epoch 114/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 1.5172
# Epoch 115/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 1.4958
# Epoch 116/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 1.4843
# Epoch 117/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 1.4467
# Epoch 118/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 1.4326
# Epoch 119/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 1.4210
# Epoch 120/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 1.3988
# Epoch 121/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 1.3840
# Epoch 122/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 1.3826
# Epoch 123/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 1.3598
# Epoch 124/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - loss: 1.3405
# Epoch 125/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 1.3296
# Epoch 126/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 1.3167
# Epoch 127/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 1.2918
# Epoch 128/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 1.2693
# Epoch 129/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 1.2757
# Epoch 130/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 1.2460
# Epoch 131/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 1.2360
# Epoch 132/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - loss: 1.2124
# Epoch 133/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 1.2097
# Epoch 134/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - loss: 1.1835
# Epoch 135/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - loss: 1.1749
# Epoch 136/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - loss: 1.1530
# Epoch 137/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - loss: 1.1347
# Epoch 138/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - loss: 1.1252
# Epoch 139/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - loss: 1.1112
# Epoch 140/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - loss: 1.0952
# Epoch 141/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 1.0833
# Epoch 142/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 1.0735
# Epoch 143/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 1.0614
# Epoch 144/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - loss: 1.0403
# Epoch 145/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 1.0286
# Epoch 146/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - loss: 1.0099
# Epoch 147/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 1.0038
# Epoch 148/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 0.9966
# Epoch 149/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - loss: 0.9799
# Epoch 150/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 0.9725
# Epoch 151/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 0.9497
# Epoch 152/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - loss: 0.9416
# Epoch 153/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 0.9387
# Epoch 154/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - loss: 0.9167
# Epoch 155/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 0.9107
# Epoch 156/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 0.8948
# Epoch 157/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - loss: 0.8801
# Epoch 158/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 0.8749
# Epoch 159/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - loss: 0.8577
# Epoch 160/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 0.8600
# Epoch 161/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 0.8378
# Epoch 162/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - loss: 0.8297
# Epoch 163/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 0.8240
# Epoch 164/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - loss: 0.8106
# Epoch 165/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 0.8031
# Epoch 166/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 0.7875
# Epoch 167/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - loss: 0.7795
# Epoch 168/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - loss: 0.7755
# Epoch 169/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - loss: 0.7561
# Epoch 170/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 0.7509
# Epoch 171/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 0.7421
# Epoch 172/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - loss: 0.7297
# Epoch 173/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 0.7243
# Epoch 174/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - loss: 0.7065
# Epoch 175/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 0.7007
# Epoch 176/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - loss: 0.6948
# Epoch 177/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 0.6830
# Epoch 178/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - loss: 0.6686
# Epoch 179/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 0.6694
# Epoch 180/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 0.6590
# Epoch 181/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - loss: 0.6486
# Epoch 182/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 0.6430
# Epoch 183/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - loss: 0.6285
# Epoch 184/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 0.6227
# Epoch 185/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - loss: 0.6079
# Epoch 186/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 0.6118
# Epoch 187/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - loss: 0.5990
# Epoch 188/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 0.6006
# Epoch 189/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - loss: 0.5818
# Epoch 190/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - loss: 0.5722
# Epoch 191/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - loss: 0.5715
# Epoch 192/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 0.5709
# Epoch 193/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - loss: 0.5498
# Epoch 194/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 0.5533
# Epoch 195/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 0.5459
# Epoch 196/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 0.5347
# Epoch 197/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - loss: 0.5382
# Epoch 198/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 0.5215
# Epoch 199/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - loss: 0.5235
# Epoch 200/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 0.5130

# %%
model.save('model.keras')

# %%
def make_reference_models():
    encoder_model_reference=k.models.Model(encoder_inputs,encoder_states)

    decoder_state_h=k.layers.Input(shape=(128,))
    decoder_state_c=k.layers.Input(shape=(128,))
    decoder_inputs_states=[decoder_state_h,decoder_state_c]

    decoder_outputs,state_h,state_c=decoder_lstm(decoder_embedding,initial_state=decoder_inputs_states)

    decoder_states=[state_h,state_c]
    decoder_outputs=decoder_dense(decoder_outputs)
    decoder_model_reference=k.models.Model([decoder_inputs]+decoder_inputs_states,[decoder_outputs]+decoder_states)


    return encoder_model_reference,decoder_model_reference

# %% [markdown]
# ## Functions :: Convert a Sentence from a String to Tokens

# %%
def str_to_tokens(sentence:str):
    words= sentence.lower().split()
    token_list= list()
    for word in words:
        try:
            token_list.append(eng_word_dict[word])
        except:
            print("The sentence is not recognised, please try again")
            run()
    return preprocessing.sequence.pad_sequences([token_list], maxlen=max_input_length, padding='post')

# %% [markdown]
# ## The Testing

# %%
def run():    
    enc_model, dec_model= make_reference_models()
    
    for sen in range(encoder_input_data.shape[0]):
        states_values= enc_model.predict(str_to_tokens (input('Enter an English sentence: ')))
        
        empty_target_seq= np.zeros((1,1))
        empty_target_seq[0,0]= ara_word_dict['start']
        stop_condition= False
        decoded_translation=''
        
        while not stop_condition:
            dec_output, h, c= dec_model.predict([empty_target_seq]+ states_values)
            sampled_word_index= np.argmax(dec_output[0,-1,:])
            sampled_word= None
            for word, index in ara_word_dict.items():
                if sampled_word_index== index:
                    decoded_translation+= ' {}'.format(word)
                    sampled_word=word
                if sampled_word== 'end' or len(decoded_translation.split()) > max_output_length:
                    stop_condition = True
            empty_target_seq= np.zeros((1,1))
            empty_target_seq[0,0]= sampled_word_index
            states_values= [h, c]
            
        print(decoded_translation[:-3])

# %%
run()
# Out:
# Enter an English sentence:  Run
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#  اركض
# Enter an English sentence:  Help
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#  النجدة
# Enter an English sentence:  Tom married a local girl
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#  توم رجل فتاة محلية
# Enter an English sentence:  Tom is reading the Bible
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#  توم يقرأ كتاباً
# Enter an English sentence:  Go on
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#  استمر
# Enter an English sentence:  free palestine
# The sentence is not recognised, please try again
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 run()
#
# Cell In[12], line 5, in run()
#       2 enc_model, dec_model= make_reference_models()
#       4 for sen in range(encoder_input_data.shape[0]):
# ----> 5     states_values= enc_model.predict(str_to_tokens (input('Enter an English sentence: ')))
#       7     empty_target_seq= np.zeros((1,1))
#       8     empty_target_seq[0,0]= ara_word_dict['start']
#
# Cell In[9], line 9, in str_to_tokens(sentence)
#       7     except:
#       8         print("The sentence is not recognised, please try again")
# ----> 9         run()
#      10 return preprocessing.sequence.pad_sequences([token_list], maxlen=max_input_length, padding='post')
#
# Cell In[12], line 5, in run()
#       2 enc_model, dec_model= make_reference_models()
#       4 for sen in range(encoder_input_data.shape[0]):
# ----> 5     states_values= enc_model.predict(str_to_tokens (input('Enter an English sentence: ')))
#       7     empty_target_seq= np.zeros((1,1))
#       8     empty_target_seq[0,0]= ara_word_dict['start']
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
